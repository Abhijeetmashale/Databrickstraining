# %% [markdown]
# ![](/Volumes/dev/abhijeet_ui/abhi_volume/Screenshot 2024-10-05 120451.png)

# %%
/Volumes/dev/abhijeet_ui/abhi_volume/Screenshot 2024-10-05 120451.png%sql
select * from dev.abhijeet_ui.customer
