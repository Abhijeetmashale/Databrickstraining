-- %%
%sql
DROP TABLE IF EXISTS dev.abhijeet_bronze.customer;
DROP TABLE IF EXISTS dev.abhijeet_bronze.invoice;
DROP TABLE IF EXISTS dev.abhijeet_bronze.contact;
DROP TABLE IF EXISTS dev.abhijeet_bronze.opportunities;
DROP TABLE IF EXISTS dev.abhijeet_bronze.opp_prod;

-- %%
%sql
create or replace table dev.abhijeet_bronze.customer as 
select * from read_files("/Volumes/dev/abhijeet_bronze/volume_b/customer.csv"); -- verify the path exists or replace with correct path 
create or replace table dev.abhijeet_bronze.Invoice as 
select * from read_files("/Volumes/dev/abhijeet_bronze/volume_b/Invoices.csv");
create or replace table dev.abhijeet_bronze.contact as 
select * from read_files("/Volumes/dev/abhijeet_bronze/volume_b/contacts.csv");
create or replace table dev.abhijeet_bronze.opportunities as 
select * from read_files("/Volumes/dev/abhijeet_bronze/volume_b/opportunity.csv");
create or replace table dev.abhijeet_bronze.opp_prod as 
select * from read_files("/Volumes/dev/abhijeet_bronze/volume_b/opportunity Prod.csv");

-- %%
%sql
Select * from dev.abhijeet_bronze.customer;
Select * from dev.abhijeet_bronze.invoice;
Select * from dev.abhijeet_bronze.contact;
Select * from dev.abhijeet_bronze.opportunities;
Select * from dev.abhijeet_bronze.opp_prod;

-- %%
drop table if exists dev.abhijeet_sliver.customer;
drop table if exists dev.abhijeet_sliver.opportunity;
