-- %%
INSERT INTO uat.bronze.transactions
  (transaction_id, from_account_id, to_account_id, transaction_type,
   amount, transaction_date, transaction_timestamp, channel,
   merchant_name, merchant_category, description, reference_number,
   status, currency, exchange_rate, fee_amount,
   location_city, location_state, device_type, ip_address,
   _rescued_data, file_name, file_path, ingestion_date)
VALUES
  ('TXN-001', 'ACC-1001', 'ACC-2001', 'PURCHASE',
   150.75, DATE'2026-07-21', TIMESTAMP'2026-07-21 10:30:00',  'MOBILE',
   'Amazon', 'E-Commerce', 'Online purchase - electronics', 'REF-001-2026',
   'COMPLETED', 'USD', 1.0, 2.50,
   'New York', 'NY', 'SMARTPHONE', '192.168.1.101',
   NULL, 'transactions_2026_07_21.json', '/Volumes/uat/bronze/stream_proj/transactions/transactions_2026_07_21.json', CURRENT_TIMESTAMP),

  ('TXN-002', 'ACC-1002', 'ACC-2002', 'TRANSFER',
   5000.00, DATE'2026-07-21', TIMESTAMP'2026-07-21 11:15:00', 'WEB',
   NULL, NULL, 'Bank transfer to savings account', 'REF-002-2026',
   'PENDING', 'USD', 1.0, 0.00,
   'Chicago', 'IL', 'DESKTOP', '10.0.0.55',
   NULL, 'transactions_2026_07_21.json', '/Volumes/uat/bronze/stream_proj/transactions/transactions_2026_07_21.json', CURRENT_TIMESTAMP);

-- %%
Overview of Data Goverance

-- %%
Data Access Control

-- %%
grant privilege on object object_name to principals
revoke privilegs on object object_name from principals

-- %%
grant use catalog on catalog dev to `account users`
