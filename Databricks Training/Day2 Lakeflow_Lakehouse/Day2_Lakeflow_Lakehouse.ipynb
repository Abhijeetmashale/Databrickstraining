-- %%
lakeflow: unified de platform within Databricks
 4 core components


1. Lakeflow connect: (Data ingestion) : external apps, db, dw ( ingest into databricks (catalog))
2. lakeflow spark declartive pipeline (Delta Live table) : Transforming ( sql, python)
3. lakeflow jobs : Orchestation tool, scheduler 
4. lakeflow designer (visual data prep):no code tool ETL

-- %%
create table if not exists dev.abhijeet_ui.Account as 
select * from read_files("/Volumes/dev/abhijeet_ui/abhi_volume/account - Copy.csv")

-- %%
select * from read_files("/Volumes/dev/abhijeet_ui/abhi_volume/account.csv")

-- %%
create table if not exists dev.abhijeet_ui.Account as 
select * from read_files(/Volumes/dev/abhijeet_ui/abhi_volume/account.csv)
