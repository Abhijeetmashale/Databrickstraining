# %%
# %sql
create table dev.abhijeet_sliver.emp(id int, name string, city string )

# %%
# %sql
insert into dev.abhijeet_sliver.emp values (2, 'Ashish', 35),(3,'Abhi', 30), (4,'Poonam', 25);

# %%
# %sql
insert into dev.abhijeet_sliver.emp values (1, 'Naval', 35);

# %%
# %sql
desc history dev.abhijeet_sliver.emp;
    
select * from dev.abhijeet_sliver.emp

# %%
# %sql
desc history dev.abhijeet_sliver.emp;

# %%
# %sql
select * from dev.abhijeet_sliver.emp version as of 1

# %%
# %sql

create table dev.abhijeet_sliver.emp_ext(id int, name string) location 's3://jpmctraining/alpha/Abhijeet'

# %%
# %sql
insert into dev.abhijeet_sliver.emp_ext values (1,'Abhi');
insert into dev.abhijeet_sliver.emp_ext values (2,'Mash');

# %%
# %sql
select * from dev.abhijeet_sliver.emp_ext

# %%
# %sql
-- Deduplicate: recreate the table keeping only distinct rows
CREATE OR REPLACE TABLE dev.abhijeet_sliver.emp_ext
LOCATION 's3://jpmctraining/alpha/Abhijeet'
AS SELECT DISTINCT * FROM dev.abhijeet_sliver.emp_ext;

SELECT * FROM dev.abhijeet_sliver.emp_ext ORDER BY id;

# %%
# %sql
update dev.abhijeet_sliver.emp_ext set name = 'Abhijeet' where id = 1

# %%
# %sql

update dev.abhijeet_sliver.emp_ext set name = 'Abhijeet' where id = 1

# %%
# %sql
SELECT DISTINCT * FROM dev.abhijeet_sliver.emp_ext

# %%
# %sql
SELECT  * FROM dev.abhijeet_sliver.emp_ext

# %%
# %sql
drop table dev.abhijeet_sliver.emp_ext

# %%
# %sql
select *  from dev.abhijeet_sliver.emp_ext

# %%
# %sql
undrop table dev.abhijeet_sliver.emp_ext

# %%
# %sql
desc history dev.abhijeet_sliver.emp;

# %%
# %sql
desc history dev.abhijeet_sliver.emp_ext

# %%
# %sql
optimize dev.abhijeet_sliver.emp_ext

# %%
# %sql
desc history dev.abhijeet_sliver.emp_ext

# %%
# %sql
vacuum dev.abhijeet_sliver.emp_ext retain 0 hours

# %%
# %sql
ALTER TABLE dev.abhijeet_sliver.emp
SET TBLPROPERTIES (
  delta.deletedFileRetentionDuration = '0 hours'
)

# %%
# %sql

ALTER TABLE dev.abhijeet_sliver.emp_ext
SET TBLPROPERTIES (
  delta.deletedFileRetentionDuration = '0 hours'
)

# %%
# %sql
optimize dev.abhijeet_sliver.emp
